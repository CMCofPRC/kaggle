# %%
import os
import sys
import warnings
import gc

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load dataset

# %%
train_X = pd.read_csv("./train.csv")
test_X = pd.read_csv("./testA.csv")

# %% [markdown]
# ## get the data type of dataset

# %%
str_cols,num_cols = Get_Dtype(train_X)

# %%
print("数值型特征：\n",num_cols)
print("str型特征：\n",str_cols)
# Out:
# 数值型特征：
#  ['id', 'loanAmnt', 'term', 'interestRate', 'installment', 'employmentTitle', 'homeOwnership', 'annualIncome', 'verificationStatus', 'isDefault', 'purpose', 'postCode', 'regionCode', 'dti', 'delinquency_2years', 'ficoRangeLow', 'ficoRangeHigh', 'openAcc', 'pubRec', 'pubRecBankruptcies', 'revolBal', 'revolUtil', 'totalAcc', 'initialListStatus', 'applicationType', 'title', 'policyCode', 'n0', 'n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9', 'n10', 'n11', 'n12', 'n13', 'n14']
# str型特征：
#  ['grade', 'subGrade', 'employmentLength', 'issueDate', 'earliesCreditLine']

# %%
train_X = train_X[num_cols].astype('float32')

# %% [markdown]
# ## general data describution

# %%
train_X.describe()
# Out:
#               id       loanAmnt           term   interestRate    installment  \
# count  800000.00  800000.000000  800000.000000  800000.000000  800000.000000
# mean   399999.75   14416.819336       3.482745      13.238389     437.947723
# std    230940.25    8716.085938       0.855832       4.765757     261.460388
# min         0.00     500.000000       3.000000       5.310000      15.690000
# 25%    199999.75    8000.000000       3.000000       9.750000     248.449997
# 50%    399999.50   12000.000000       3.000000      12.740000     375.135010
# 75%    599999.25   20000.000000       3.000000      15.990000     580.710022
# max    799999.00   40000.000000       5.000000      30.990000    1715.420044
#
#        employmentTitle  homeOwnership  annualIncome  verificationStatus  \
# count    799999.000000  800000.000000  8.000000e+05       800000.000000
# mean      72005.351562       0.614213  7.613390e+04            1.009683
# ...

# %%
# %run EDA_utils.ipynb

# %% [markdown]
# ## plot the category feature

# %%
for col in num_cols:
    if col != 'title':
        Numerical_BoxPlot(df= train_X, col= col)
