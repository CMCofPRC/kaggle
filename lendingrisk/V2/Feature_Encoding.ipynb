# %%
import os
import gc
import warnings
import random

import pandas as pd
import numpy as np
 
# %run Feature_Cleaning_utils.ipynb
# %run Page_Style.ipynb
warnings.filterwarnings(action='ignore')
# Out:
# <style>
#     div#notebook-container    { width: 100%; }
#     div#menubar-container     { width: 90%; }
#     div#maintoolbar-container { width: 99%; }
#     div#maintoolbar{background:#e5e5e5;}
# </style>
# <style>
#     div#notebook-container    { width: 100%; }
#     div#menubar-container     { width: 90%; }
#     div#maintoolbar-container { width: 99%; }
#     div#maintoolbar{background:#e5e5e5;}
# </style>

# %%
train_X = pd.read_csv("./train_filled_Outliers_Rarehandled.csv")

# %%
train_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800000 entries, 0 to 799999
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       800000 non-null  int64
#  1   loanAmnt                 800000 non-null  float64
#  2   term                     800000 non-null  int64
#  3   interestRate             800000 non-null  float64
#  4   installment              800000 non-null  float64
#  5   grade                    800000 non-null  int64
#  6   subGrade                 800000 non-null  int64
#  7   employmentTitle          800000 non-null  float64
#  8   employmentLength         800000 non-null  float64
#  9   homeOwnership            800000 non-null  int64
#  10  annualIncome             800000 non-null  float64
#  11  verificationStatus       800000 non-null  int64
#  12  isDefault                800000 non-null  int64
# ...

# %% [markdown]
# # Encoding

# %%
for idx in train_X.columns:
    Encoding_Get_Value_Counts(train_X, col = idx)
# Out:
# id完整的数值统计：
# 0         1
# 533350    1
# 533328    1
# 533329    1
# 533330    1
#          ..
# 266668    1
# 266669    1
# 266670    1
# 266671    1
# 799999    1
# Name: id, Length: 800000, dtype: int64
# loanAmnt完整的数值统计：
# 10000.0     59068
# 12000.0     43291
# 20000.0     41885
# 15000.0     41629
# 999999.0    35315
#             ...
# 21400.0       101
# 16850.0       101
# 14875.0       101
# 9625.0        101
# 24950.0       101
# Name: loanAmnt, Length: 653, dtype: int64
# term完整的数值统计：
# 3    606902
# 5    193098
# Name: term, dtype: int64
# interestRate完整的数值统计：
# 10.99    22549
# 11.99    19674
# 13.99    17420
# 5.32     17033
# 9.17     15523
#          ...
# 16.95       12
# 9.64        12
# 11.28       11
# 20.85       11
# 17.39       11
# Name: interestRate, Length: 471, dtype: int64
# installment完整的数值统计：
# 999999.00    21990
# 327.34        1843
# 301.15        1592
# 332.10        1543
# 318.79        1358
#              ...
# 306.57           2
# ...

# %%
train_X.columns
# Out:
# Index(['id', 'loanAmnt', 'term', 'interestRate', 'installment',
#        'employmentTitle', 'employmentLength', 'homeOwnership', 'annualIncome',
#        'verificationStatus', 'isDefault', 'purpose', 'postCode', 'regionCode',
#        'dti', 'delinquency_2years', 'ficoRangeLow', 'ficoRangeHigh', 'openAcc',
#        'pubRec', 'pubRecBankruptcies', 'revolBal', 'revolUtil', 'totalAcc',
#        'initialListStatus', 'applicationType', 'title', 'policyCode', 'n0',
#        'n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9', 'n10', 'n11',
#        'n12', 'n13', 'n14', 'issueDate_year', 'issueDate_month',
#        'earliesCreditLine_year', 'earliesCreditLine_month'],
#       dtype='object')
